# %%
import seaborn as sns # pip install seaborn
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 tips.head()
#
# NameError: name 'tips' is not defined

# %%
#Assignment
# tips is a pandas dataframe.
# try to use some methods from previous classes to plot some data out of this.
# This assignment is not required to be submitted but you must have atlease 1 graph plot ready by Saturday
