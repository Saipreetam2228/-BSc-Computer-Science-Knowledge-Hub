# %%
"""
Practice Questions
1. Find the common elements of two lists. Define your own lists.
2. Find the number of vowels in a string. Take string as user input.
3. CHeck if an string is a pallindrone (reverse is same as string eg. "aba",  "abcdcba")
4. Print the fibonacci sequence upto "n" numbers.(take n as input from user)
5. Given two numbers, find their LCM and HCF. Take these two numbers as user input.
6. Find the sum of the greatest three numbers from a list. Define your own list(greater than 3 elements)
"""
